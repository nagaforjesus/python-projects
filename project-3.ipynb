# %% [markdown]
# <a href="https://colab.research.google.com/github/nagaforjesus/python-projects/blob/main/project-3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os  # 'os' library to change the working directory
import pandas as pd
import numpy as np

# %% [markdown]
# # **Problem 1**

# %%
taxi_data = pd.read_csv("/content/drive/MyDrive/Lecture_7/taxi_tripdata.csv",na_values=["??","????"])
# Out:
# <ipython-input-3-5cd9ab545073>:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   taxi_data = pd.read_csv("/content/drive/MyDrive/Lecture_7/taxi_tripdata.csv",na_values=["??","????"])

# %%
taxi_data.shape
# Out:
# (83691, 20)

# %%
taxi_data.sample(frac=0.1)  # Want to work with just 10% of the data
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 13799       2.0  2021-07-09 13:35:59   2021-07-09 14:49:25                  N
# 75947       NaN  2021-07-18 21:15:00   2021-07-18 21:39:00                NaN
# 4583        2.0  2021-07-03 14:58:14   2021-07-03 15:05:26                  N
# 46238       1.0  2021-07-29 09:23:48   2021-07-29 09:35:05                  N
# 75892       NaN  2021-07-06 14:11:00   2021-07-06 14:46:00                NaN
# ...         ...                  ...                   ...                ...
# 34366       2.0  2021-07-21 23:03:38   2021-07-21 23:13:51                  N
# 48070       2.0  2021-07-30 10:59:43   2021-07-30 11:13:28                  N
# 50664       2.0  2021-07-31 17:58:05   2021-07-31 19:14:14                  N
# 30215       2.0  2021-07-19 11:18:58   2021-07-19 11:30:12                  N
# 19704       2.0  2021-07-13 08:52:17   2021-07-13 09:01:56                  N
#
# ...

# %%
taxi_data.sample(10, random_state=0)
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 75307       NaN  2021-07-29 08:24:00   2021-07-29 08:50:00                NaN
# 32123       2.0  2021-07-20 14:29:02   2021-07-20 14:45:08                  N
# 3364        1.0  2021-07-02 18:52:09   2021-07-02 18:57:56                  N
# 11359       2.0  2021-07-07 21:49:41   2021-07-07 21:55:46                  N
# 51298       NaN  2021-07-02 08:29:00   2021-07-02 08:53:00                NaN
# 64452       NaN  2021-07-28 12:21:00   2021-07-28 13:25:00                NaN
# 4688        2.0  2021-07-03 16:43:12   2021-07-03 16:53:46                  N
# 16366       2.0  2021-07-10 20:21:49   2021-07-10 20:35:25                  N
# 65522       NaN  2021-07-14 00:06:00   2021-07-14 00:16:00                NaN
# 66523       NaN  2021-07-30 12:15:00   2021-07-30 12:46:00                NaN
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# ...

# %%
taxi_data["trip_distance"].sample(frac=0.1).plot.line()
# Out:
# <Axes: >

# %%
taxi_data = taxi_data.drop(["store_and_fwd_flag","ehail_fee"], axis=1) # To drop the columns
taxi_data
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime  RatecodeID  \
# 0           1.0  2021-07-01 00:30:52   2021-07-01 00:35:36         1.0
# 1           2.0  2021-07-01 00:25:36   2021-07-01 01:01:31         1.0
# 2           2.0  2021-07-01 00:05:58   2021-07-01 00:12:00         1.0
# 3           2.0  2021-07-01 00:41:40   2021-07-01 00:47:23         1.0
# 4           2.0  2021-07-01 00:51:32   2021-07-01 00:58:46         1.0
# ...         ...                  ...                   ...         ...
# 83686       NaN  2021-07-02 07:59:00   2021-07-02 08:33:00         NaN
# 83687       NaN  2021-07-02 07:02:00   2021-07-02 07:18:00         NaN
# 83688       NaN  2021-07-02 07:53:00   2021-07-02 08:15:00         NaN
# 83689       NaN  2021-07-02 07:58:00   2021-07-02 08:30:00         NaN
# 83690       NaN  2021-07-02 07:00:00   2021-07-02 07:26:00         NaN
#
#        PULocationID  DOLocationID  passenger_count  trip_distance  \
# ...

# %%
taxi_data.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime  RatecodeID  \
# 0       1.0  2021-07-01 00:30:52   2021-07-01 00:35:36         1.0
# 1       2.0  2021-07-01 00:25:36   2021-07-01 01:01:31         1.0
# 2       2.0  2021-07-01 00:05:58   2021-07-01 00:12:00         1.0
# 3       2.0  2021-07-01 00:41:40   2021-07-01 00:47:23         1.0
# 4       2.0  2021-07-01 00:51:32   2021-07-01 00:58:46         1.0
#
#    PULocationID  DOLocationID  passenger_count  trip_distance  fare_amount  \
# 0            74           168              1.0           1.20          6.0
# 1           116           265              2.0          13.69         42.0
# 2            97            33              1.0           0.95          6.5
# 3            74            42              1.0           1.24          6.5
# 4            42           244              1.0           1.10          7.0
#
#    extra  mta_tax  tip_amount  tolls_amount  improvement_surcharge  \
# ...

# %% [markdown]
# # **Problem 2**

# %% [markdown]
# **Building a Pandas Dataframe**
# *   If you are working with data in Python, then you'll most likely need to have the data in Pandas Dataframe. This is basiaclly a tabular represenatation of the data with rows and columns. Let's assume you want to create the following datafrane in Python.
#
#   ![image.png](data:image/png;base64,...)

# %%
df = pd.DataFrame(columns=["name","age","height", "Country"])  # Currently the dataframe is empty
df
# Out:
# Empty DataFrame
# Columns: [name, age, height, Country]
# Index: []

# %%
df.loc[0] = ["Kindson",39, 185,"Budapest" ]
df.loc[1] = ["Jordan",34, 170,"Stockholm" ]
df.loc[2] = ["Mike",25, 165,"Bangalore" ]
df.loc[3] = ["John",22, 155,"Niamey" ]
df
# Out:
#       name  age  height    Country
# 0  Kindson   39     185   Budapest
# 1   Jordan   34     170  Stockholm
# 2     Mike   25     165  Bangalore
# 3     John   22     155     Niamey

# %%
df = pd.DataFrame([[1, 2], [3, 4]], columns=list('AB'), index=['x', 'y'])
df2 = pd.DataFrame([[5, 6], [7, 8]], columns=list('AB'), index=['x', 'y'])
df.append(df2)
# Out:
# <ipython-input-19-fc6800084d5b>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(df2)
#    A  B
# x  1  2
# y  3  4
# x  5  6
# y  7  8

# %% [markdown]
# ## **Problem 3**

# %% [markdown]
# 1. Define a **two dimensional dataframe**. You can **create a dataframe** from a **python dictionary**

# %%
bank_client_df = pd.DataFrame({'Bank_Client_ID' : [111, 222, 333,444],
                               'Banl_Client_Name' : ['Mark Arey', 'Nicole Mitch', 'Kata Steve','Joe Edertan'],
                               'Net_worth [$]':[35000, 3000, 100000, 2000],
                               'Years_with_Bank' : [3, 7, 10, 20]})
bank_client_df
# Out:
#    Bank_Client_ID Banl_Client_Name  Net_worth [$]  Years_with_Bank
# 0             111        Mark Arey          35000                3
# 1             222     Nicole Mitch           3000                7
# 2             333       Kata Steve         100000               10
# 3             444      Joe Edertan           2000               20

# %% [markdown]
# 2. View **first couple of raw**s in the dataframe

# %%
bank_client_df.head(2)
# Out:
#    Bank_Client_ID Banl_Client_Name  Net_worth [$]  Years_with_Bank
# 0             111        Mark Arey          35000                3
# 1             222     Nicole Mitch           3000                7

# %% [markdown]
# 3. View the **last couple of raws** in the dataframe

# %%
bank_client_df.tail(2)
# Out:
#    Bank_Client_ID Banl_Client_Name  Net_worth [$]  Years_with_Bank
# 2             333       Kata Steve         100000               10
# 3             444      Joe Edertan           2000               20

# %% [markdown]
# 4. What is the shape of the dataframe?

# %%
bank_client_df.shape
# Out:
# (4, 4)

# %% [markdown]
# 5. Obtain the dataframe information.

# %%
bank_client_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Bank_Client_ID    4 non-null      int64
#  1   Banl_Client_Name  4 non-null      object
#  2   Net_worth [$]     4 non-null      int64
#  3   Years_with_Bank   4 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 256.0+ bytes

# %% [markdown]
# # **Problem 4**

# %%
data = {
        'name' : ['Xavier', 'Ann', 'Yi', 'Robin', 'Amal', 'Nori'],
        'city' : ['Mexico City', 'Toronto','Shanghai', 'Prague','Manchester', 'Osaka'],
        'age' : [41, 28, 35, 38, 37, 31],
        'py_score' : [88.0, 98.0, 61.0, 84.0, 79.0, 61.0]
}
index = range(101, 107)

# %%
df = pd.DataFrame(data, index=index)
df
# Out:
#        name         city  age  py_score
# 101  Xavier  Mexico City   41      88.0
# 102     Ann      Toronto   28      98.0
# 103      Yi     Shanghai   35      61.0
# 104   Robin       Prague   38      84.0
# 105    Amal   Manchester   37      79.0
# 106    Nori        Osaka   31      61.0

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.index
# Out:
# RangeIndex(start=101, stop=107, step=1)

# %%
df.columns
# Out:
# Index(['name', 'city', 'age', 'py_score'], dtype='object')

# %%
df['city']
# Out:
# 101    Mexico City
# 102        Toronto
# 103       Shanghai
# 104         Prague
# 105     Manchester
# 106          Osaka
# Name: city, dtype: object

# %%
df.head()   # Display the first five raws of the data set
# Out:
#        name         city  age  py_score
# 101  Xavier  Mexico City   41      88.0
# 102     Ann      Toronto   28      98.0
# 103      Yi     Shanghai   35      61.0
# 104   Robin       Prague   38      84.0
# 105    Amal   Manchester   37      79.0

# %%
df.loc[103]
# Out:
# name              Yi
# city        Shanghai
# age               35
# py_score        61.0
# Name: 103, dtype: object

# %%
type(df.loc[103])    # Accessing Panda Dataframe Series Object
# Out:
# pandas.core.series.Series

# %%
df.city
# Out:
# 101    Mexico City
# 102        Toronto
# 103       Shanghai
# 104         Prague
# 105     Manchester
# 106          Osaka
# Name: city, dtype: object

# %% [markdown]
# **Create a DataFrame from a Numpy array. We will also learn how to specify the index and the column headers of the DataFrame**

# %% [markdown]
# # **Problem 6**
# 1. Import the Pandas and Numpy modules.
# 2. Create a Numpy array.
# 3. Create list of index values and column values for the DataFrame.
# 4. Create the DataFrame.
# 5. Display the DataFrame.

# %%
# importiong the modules
import pandas as pd
import numpy as np

# creating the Numpy array
array = np.array([[1, 1, 1], [2, 4, 8], [3, 9, 27],
                  [4, 16, 64], [5, 25, 125], [6, 36, 216],
                  [7, 49, 343]])

# creating a list of index names
index_values = ['first', 'second', 'third',
                'fourth', 'fifth', 'sixth', 'seventh']

# creating a list of column names
column_values = ['number', 'squares', 'cubes']

# creating the dataframe
df = pd.DataFrame(data = array,
                  index = index_values,
                  columns = column_values)

# displaying the dataframe
print(df)
# Out:
#          number  squares  cubes
# first         1        1      1
# second        2        4      8
# third         3        9     27
# fourth        4       16     64
# fifth         5       25    125
# sixth         6       36    216
# seventh       7       49    343

# %%
# importiong the modules
import pandas as pd
import numpy as np

# creating the Numpy array
array = np.array([['Aditya', 20], ['Samruddhi', 15],
                  ['Rohan', 21], ['Anantha', 20],
                  ['Abhinandan', 21]])

# creating a list of index names
index_values = ['A', 'B', 'C', 'D', 'E']

# creating a list of column names
column_values = ['Names', 'Age']

# creating the dataframe
df = pd.DataFrame(data = array,
                  index = index_values,
                  columns = column_values)

# displaying the dataframe
print(df)
# Out:
#         Names Age
# A      Aditya  20
# B   Samruddhi  15
# C       Rohan  21
# D     Anantha  20
# E  Abhinandan  21

# %%
# importiong the modules
import pandas as pd
import numpy as np

# creating the Numpy array
array = np.array([['CEO', 20, 5], ['CTO', 22, 4.5],
                  ['CFO', 21, 3], ['CMO', 24, 2]])

# creating a list of index names
index_values = [1, 2, 3, 4]

# creating a list of column names
column_values = ['Names', 'Age',
                 'Net worth in Millions']

# creating the dataframe
df = pd.DataFrame(data = array,
                  index = index_values,
                  columns = column_values)

# displaying the dataframe
print(df)
# Out:
#   Names Age Net worth in Millions
# 1   CEO  20                     5
# 2   CTO  22                   4.5
# 3   CFO  21                     3
# 4   CMO  24                     2
